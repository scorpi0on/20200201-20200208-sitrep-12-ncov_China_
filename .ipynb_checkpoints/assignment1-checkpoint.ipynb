# %% [markdown]
# # COMP7930 Big Data Analytics
#
# # Assignment 1 Data Visualization using Python
#
# ---
#
# | Students Name | ID |
# |---|---|
# | 💡 Chen Xin| 💡 19437471 |
#
# * Lecturer: [Dr. Kevin Wang](mailto:kevinw@comp.hkbu.edu.hk)
# * TA in-charge: [Ningxia Wang](mailto:nxwang@comp.hkbu.edu.hk)
#
#
# Assignment Due: 21/2/2020 (Friday)
#
# Submission: Submit this `ipynb` file and the `csv` file for your Q3 to Moodle.
#
# ---
#
# ## Packages you should install
#
# To begin with, you should download this `ipynb` file with your *jupyter notebook*. Please refer to the lecture note to install and launch jupyter notebook.
#
# You are required to install the following packages. It is recommended to use `pip` to install these packages:
# * `jupyter notebook`
# * `seaborn`
# * `matplotlib`
# * `pandas`
#
# Jupyter notebook, or the *notebook*, is our integrated development environment (IDE).
#
#
# Python has long been great for data munging and preparation, but less so for data analysis and modeling.
# `Pandas` helps filling this gap, enables you to carry out your data analysis workflow in Python without having to switch to a more domain specific language like R. `Pandas` is an open source, BSD-licensed library providing high-performance, easy-to-use data structures and data analysis tools for the Python programming language.
#
# The `matplotlib` API can be used to create decent plots such as bar graphs, histograms, scatter plots, etc. It allows you to perform many fine-grained control in plotting graph.
#
# `Seaborn` built on `matplotlib` provides a high-level interface for drawing attractive and informative statistical graphics. That means you are allowed to visualize your data in a very convenient way.
#
# Note: We assume the use of Python 3.8 or above.
#
# ## How to do this assignment?
#
# The first half of the assignment is a guided tutorial that allow you to run the code and observe the result. The second half of the assignment requires you to produce certain code for visualization. Look for the 💡 symbol that action is required.

# %% [markdown]
# ---
#
# # Basic Operation - Let's eat some Avocados
#
# Download the dataset `avocado.csv` which contains a weekly retail and price of avocado in 2018. Run the following code to read the data. Make sure you have placed `avocado.csv` in the same directory as your notebook.
#
# (To run the code below, click the cell and click `Cell` > `Run Cells` on the menu bar to run it. Or simple press `Ctrl-Enter`)

# %%
import pandas as pd
pd.set_option('display.float_format', lambda x: '%.3f' % x)
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv('avocado.csv', index_col='Date', parse_dates=True)
df.head()
# Out:
#             AveragePrice  Total Volume     4046       4225    4770  \
# Date
# 2015-12-27         1.330     64236.620 1036.740  54454.850  48.160
# 2015-12-20         1.350     54876.980  674.280  44638.810  58.330
# 2015-12-13         0.930    118220.220  794.700 109149.670 130.500
# 2015-12-06         1.080     78992.150 1132.000  71976.410  72.580
# 2015-11-29         1.280     51039.600  941.480  43838.390  75.780
#
#             Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# Date
# 2015-12-27    8696.870    8603.620      93.250        0.000  conventional
# 2015-12-20    9505.560    9408.070      97.490        0.000  conventional
# 2015-12-13    8145.350    8042.210     103.140        0.000  conventional
# 2015-12-06    5811.160    5677.400     133.760        0.000  conventional
# 2015-11-29    6183.950    5986.260     197.690        0.000  conventional
#
#             region
# Date
# 2015-12-27  Albany
# 2015-12-20  Albany
# 2015-12-13  Albany
# 2015-12-06  Albany
# 2015-11-29  Albany

# %% [markdown]
# The above code read the data into the variable `df` as a **DataFrame**. A DataFrame can be considered as a row of data in Pandas. We print the first five rows in the `df` by `df.head()`.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 17911 entries, 2015-12-27 to 2018-01-07
# Data columns (total 11 columns):
# AveragePrice    17911 non-null float64
# Total Volume    17911 non-null float64
# 4046            17911 non-null float64
# 4225            17911 non-null float64
# 4770            17911 non-null float64
# Total Bags      17911 non-null float64
# Small Bags      17911 non-null float64
# Large Bags      17911 non-null float64
# XLarge Bags     17911 non-null float64
# type            17911 non-null object
# region          17911 non-null object
# dtypes: float64(9), object(2)
# memory usage: 1.6+ MB

# %% [markdown]
# The command `df.info()` explain in more details about what are the types of these columns. These columns can be understood as
#
# | Column Name | Explanation |
# |:--|:--|
# | Date (Index) | the date of the observation. |
# |AveragePrice| the average price of a single avocado.|
# |Total Volume| total number of avocados sold.|
# |4046| total number of avocados with PLU 4046 sold.|
# |4225| total number of avocados with PLU 4225 sold.|
# |4770| total number of avocados with PLU 4770 sold.|
# |Total Bags| avocados are packed up in bags and bags may have three types: Small Bags, Large Bags and XLarge Bags. Total Bags indicates the sum of bags used for packaging.|
# |Small Bags| the sum of small bags used for packaging.|
# |Large Bags| the sum of large bags used for packaging.|
# |XLarge Bags| the sum of xlarge bags used for packaging.|
# |type| conventional or organic|
# |region| the city or region of the observation|

# %% [markdown]
# # Column Slicing
#
# Sometime we don't need that many columns, especially when we want to plot data into a graph. In this case we will need to remove some columns or to copy those columns into a new variable. `df['COLUMN_NAME']` is a reference to a particular column by referencing its name.

# %%
df['4770']
# Out:
# Date
# 2015-12-27    48.160
# 2015-12-20    58.330
# 2015-12-13   130.500
# 2015-12-06    72.580
# 2015-11-29    75.780
#                ...
# 2018-02-04     0.000
# 2018-01-28     0.000
# 2018-01-21   727.940
# 2018-01-14   727.010
# 2018-01-07   224.530
# Name: 4770, Length: 17911, dtype: float64

# %% [markdown]
# Note that the index is ALWAYS staying with the DataFrame. We could also slice more than one column at a time:

# %%
#We need two [] symbols when we want to have multiple columns. The inner [] make the columns as a list
df[['4770','4046', '4225']]
# Out:
#               4770     4046       4225
# Date
# 2015-12-27  48.160 1036.740  54454.850
# 2015-12-20  58.330  674.280  44638.810
# 2015-12-13 130.500  794.700 109149.670
# 2015-12-06  72.580 1132.000  71976.410
# 2015-11-29  75.780  941.480  43838.390
# ...            ...      ...        ...
# 2018-02-04   0.000 2046.960   1529.200
# 2018-01-28   0.000 1191.700   3431.500
# 2018-01-21 727.940 1191.920   2452.790
# 2018-01-14 727.010 1527.630   2981.040
# 2018-01-07 224.530 2894.770   2356.130
#
# [17911 rows x 3 columns]

# %% [markdown]
# Suppose we also want to add a column called total income by multiplying `AveragePrice` and `Total Volume`, we can do it by:

# %%
df['income'] = df['AveragePrice'] * df['Total Volume']
df.head()
# Out:
#             AveragePrice  Total Volume     4046       4225    4770  \
# Date
# 2015-12-27         1.330     64236.620 1036.740  54454.850  48.160
# 2015-12-20         1.350     54876.980  674.280  44638.810  58.330
# 2015-12-13         0.930    118220.220  794.700 109149.670 130.500
# 2015-12-06         1.080     78992.150 1132.000  71976.410  72.580
# 2015-11-29         1.280     51039.600  941.480  43838.390  75.780
#
#             Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 2015-11-29  Albany
# 2015-11-22  Albany
# 2015-11-15  Albany
# 2015-11-08  Albany
# 2015-11-01  Albany
# 2015-10-25  Albany

# %% [markdown]
# Here `0:10` refers a range of number 0, 1, 2, 3, 4,.. 9 (excluded 10). These index in python is very command and we can actually put a negative number to indicate rows counted from the tail. For example, the last 6 rows of data:

# %%
df.iloc[-7:-1]
# Out:
#             AveragePrice  Total Volume     4046     4225    4770  Total Bags  \
# Date
# 2018-02-18         1.560     17597.120 1892.050 1928.360   0.000   13776.710
# 2018-02-11         1.570     15986.170 1924.280 1368.320   0.000   12693.570
# 2018-02-04         1.630     17074.830 2046.960 1529.200   0.000   13498.670
# 2018-01-28         1.710     13888.040 1191.700 3431.500   0.000    9264.840
# 2018-01-21         1.870     13766.760 1191.920 2452.790 727.940    9394.110
# 2018-01-14         1.930     16205.220 1527.630 2981.040 727.010   10969.540
#
#             Small Bags  Large Bags  XLarge Bags     type            region
# Date
# 2018-02-18   13553.530     223.180        0.000  organic  WestTexNewMexico
# 2018-02-11   12437.350     256.220        0.000  organic  WestTexNewMexico
# 2018-02-04   13066.820     431.850        0.000  organic  WestTexNewMexico
# 2018-01-28    8940.040     324.800        0.000  organic  WestTexNewMexico
# 2018-01-21    9351.800      42.310        0.000  organic  WestTexNewMexico
# 2018-01-14   10919.540      50.000        0.000  organic  WestTexNewMexico

# %% [markdown]
# Using `df.loc[KEYS or CONDITIONS]` allows us to filter the row we want. Remember the index of our DataFrame is `Date`.

# %%
df.loc[df.index >'2018-02-11']
# Out:
#             AveragePrice  Total Volume      4046       4225   4770  \
# Date
# 2018-03-25         1.570    149396.500 16361.690 109045.030 65.450
# 2018-03-18         1.350    105304.650 13234.860  61037.580 55.000
# 2018-03-11         1.120    144648.750 15823.350 110950.680 70.000
# 2018-03-04         1.080    139520.600 12002.120 105069.570 95.620
# 2018-02-25         1.280    104278.890 10368.770  59723.320 48.000
# ...                  ...           ...       ...        ...    ...
# 2018-03-18         1.560     15896.380  2055.350   1499.550  0.000
# 2018-03-11         1.560     22128.420  2162.670   3194.250  8.930
# 2018-03-04         1.540     17393.300  1832.240   1905.570  0.000
# 2018-02-25         1.570     18421.240  1974.260   2482.650  0.000
# 2018-02-18         1.560     17597.120  1892.050   1928.360  0.000
#
#             Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# Date
# 2018-03-25   23924.330   19273.800    4270.530      380.000  conventional
# 2018-03-18   30977.210   26755.900    3721.310      500.000  conventional
# 2018-03-11   17804.720   14480.520    3033.090      291.110  conventional
# 2018-03-04   22353.290   16128.510    5941.450      283.330  conventional
# 2018-02-25   34138.800   30126.310    3702.490      310.000  conventional
# ...                ...         ...         ...          ...           ...
# 2018-03-18   12341.480   12114.810     226.670        0.000       organic
# 2018-03-11   16762.570   16510.320     252.250        0.000       organic
# 2018-03-04   13655.490   13401.930     253.560        0.000       organic
# 2018-02-25   13964.330   13698.270     266.060        0.000       organic
# 2018-02-18   13776.710   13553.530     223.180        0.000       organic
#
#                       region
# Date
# 2018-03-25            Albany
# 2018-03-18            Albany
total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# Date
# 2015-12-27    8696.870    8603.620      93.250        0.000  conventional
# 2015-12-20    9505.560    9408.070      97.490        0.000  conventional
# 2015-12-13    8145.350    8042.210     103.140        0.000  conventional
# 2015-12-06    5811.160    5677.400     133.760        0.000  conventional
# 2015-11-29    6183.950    5986.260     197.690        0.000  conventional
# ...                ...         ...         ...          ...           ...
# 2018-02-04   13498.670   13066.820     431.850        0.000       organic
# 2018-01-28    9264.840    8940.040     324.800        0.000       organic
# 2018-01-21    9394.110    9351.800      42.310        0.000       organic
# 2018-01-14   10969.540   10919.540      50.000        0.000       organic
# 2018-01-07   12014.150   11988.140      26.010        0.000       organic
#
#                       region
# Date
# 2015-12-27            Albany
# 2015-12-20            Albany
# 2015-12-13            Albany
# 2015-12-06            Albany
# 2015-11-29            Albany
# ...                      ...
# 2018-02-04  WestTexNewMexico
# 2018-01-28  WestTexNewMexico
# 2018-01-21  WestTexNewMexico
# 2018-01-14  WestTexNewMexico
# 2018-01-07  WestTexNewMexico
#
# [9123 rows x 11 columns]

# %% [markdown]
# ---
#
# # Basic Statistics
#
# We can use `df.describe()` to get the summarized statistucs of the DataFrame.

# %%
df.describe()
# Out:
#        AveragePrice  Total Volume        4046        4225       4770  \
# count     17911.000     17911.000   17911.000   17911.000  17911.000
# mean          1.408    539258.691  183807.409  188223.112  14551.234
# std           0.404   1224331.914  515105.861  451985.648  48817.537
# min           0.440        84.560       0.000       0.000      0.000
# 25%           1.100     10571.020     819.660    2909.610      0.000
# 50%           1.370    100154.130    7824.430   26701.990    164.230
# 75%           1.670    400176.680  101488.815  131755.215   5736.735
# max           3.250  11274749.110 5160896.680 5402444.450 804558.250
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags
# count   17911.000   17911.000   17911.000    17911.000
# mean   152675.731  116202.869   34505.694     1967.168
# std    364599.231  278759.604  113947.739     8186.402
# min         0.000       0.000       0.000        0.000
# 25%      4905.195    2700.335     112.995        0.000
# 50%     37551.020   24530.620    2459.220        0.000
# 75%    103691.600   79282.590   19421.705      106.760
# max   4145406.700 3403581.490 2838239.390   131300.760

# %%
df.describe(include=np.object)  # describe categorical data
# Out:
#                 type         region
# count          17911          17911
# unique             2             53
# top     conventional  SouthCarolina
# freq            8957            338

# %%
print(df.max(numeric_only=True)) # describe the max value of each row; process only the numeric data.
# Out:
# AveragePrice          3.250
# Total Volume   11274749.110
# 4046            5160896.680
# 4225            5402444.450
# 4770             804558.250
# Total Bags      4145406.700
# Small Bags      3403581.490
# Large Bags      2838239.390
# XLarge Bags      131300.760
# dtype: float64

# %%
print(df['AveragePrice'].max()) # describe the max value on a particular column only
# Out:
# 3.25

# %% [markdown]
# In additioinal to `.max()`, you might find the following functions useful:
#
# | function | meaning |
# |:--|:--|
# | `.max()` | Maximum of a column |
# | `.min()` | Minimum of a column |
# | `.mean()` | Average of a column |
# | `.median()` | Median of a column |
# | `.mode()` | Mode of a column |
# | `.count()` | Total number non `NA` (not available) value of a column |
# | `.sum()` | Sum of a column |
# | `.product()` | Product of a column |
#
#
#
# > More details please visit https://pandas.pydata.org/pandas-docs/stable/reference/frame.html#computations-descriptive-stats
#
# ## Groupby
#
# Sometime we want to group data by some attributes and output the statistic of that group. This function is similar to pivot table in Excel. Pivot table is a rather less frequently used feature, but it is extremely powerful in analysis.
#
# Suppose we want to see how many 4046 is sold for each region. Without using the feature groupby, we will need to manually filter each region by
# ```py
# df.loc[df['region'] == 'Albany']['4046'].mean()
# df.loc[df['region'] == 'Atlanta']['4046'].mean()
# df.loc[df['region'] == 'BaltimoreWashington']['4046'].mean()
# ```
# which is very inconvenient. Besides, you will need to know all possible name of region in order to write your code. The following code save a lot of efforts.

# %%
df.groupby('region')['4046'].mean()
# Out:
# region
# Albany                   1824.082
# Atlanta                146116.868
# BaltimoreWashington     35656.218
# Boise                   20019.508
# Boston                   4994.610
# BuffaloRochester         1776.671
# California            1180375.778
# Charlotte               22378.138
# Chicago                 32083.082
# CincinnatiDayton         5411.698
# Columbus                37237.064
# DallasFtWorth          327090.140
# Denver                  78191.868
# Detroit                 55571.451
# GrandRapids              1459.368
# GreatLakes             277269.265
# HarrisburgScranton      22235.269
# HartfordSpringfield      3904.301
# Houston                295186.092
# Indianapolis             7176.066
# Jacksonville            45774.290
# LasVegas                58541.809
# LosAngeles             662364.981
# Louisville               2099.263
# MiamiFtLauderdale      174970.709
# Midsouth               326717.850
# Nashville               53813.269
# NewOrleansMobile        79303.962
# NewYork                 22601.559
# Northeast              103524.283
# NorthernNewEngland       7997.724
# Orlando                 98789.660
# Philadelphia            13654.441
# PhoenixTucson          341502.099
# Pittsburgh              11752.771
# Plains                 424589.825
# Portland                68662.501
# RaleighGreensboro       34972.819
# RichmondNorfolk         36913.755
# Roanoke                 22050.136
# Sacramento              69382.852
# SanDiego               100836.291
# SanFrancisco           100996.715
# Seattle                 63510.809
# SouthCarolina           84054.324
# SouthCentral          1582962.683
# Southeast             1004991.399
# Spokane                 12142.221
# StLouis                 39972.935
# Syracuse                  981.623
# Tampa                  105762.579
# West                  1179261.927
# WestTexNewMexico       250977.271
# Name: 4046, dtype: float64

# %% [markdown]
# > Note: A function is needed to follow the use of groupby. It is because each row being grouped has a different value in that column. We need a function to *aggregate* these values.

# %% [markdown]
# # Plotting Data into a graph
#
# In our lecture note we have given several examples about plotting temporal data (time) and non-temporal data. On top of those, we present some other examples here.
#
# The following example tries to plot the sales of different types of avocados:

# %%
plt.figure(figsize=(12,6))
plt.title("Different types of Avocados Sales from 2015 to 2018")
sns.lineplot(data=df['4046'], label='4046')
sns.lineplot(data=df['4225'], label='4225')
sns.lineplot(data=df['4770'], label='4770')
plt.ylabel('Sales Volume')
plt.xlabel('Year')
plt.show()
# Out:
# /Users/chenxin/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %%
# Suppose we want to show data only from 2017 to 2018
plt.figure(figsize=(12,6))
plt.title("Different types of Avocados Sales from 2017 to 2018")
sns.lineplot(data=df['4046'].loc[df.index>'2017-1-1'], label='4046')
sns.lineplot(data=df['4225'].loc[df.index>'2017-1-1'], label='4225')
sns.lineplot(data=df['4770'].loc[df.index>'2017-1-1'], label='4770')
plt.ylabel('Sales Volume')
plt.xlabel('Year')
plt.show()

# %%
# Alternatively we can do 
newdf = df.loc[df.index > '2017-1-1']  # create a new variable newdf
plt.figure(figsize=(12,6))
plt.title("Different types of Avocados Sales from 2017 to 2018")
sns.lineplot(data=newdf['4046'], label='4046')
sns.lineplot(data=newdf['4225'], label='4225')
sns.lineplot(data=newdf['4770'], label='4770')
plt.ylabel('Sales Volume')
plt.xlabel('Year')
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.title("Correlation of data")
sns.heatmap(df.corr(), annot=True) # df.corr() produces the correlation between data
plt.show()

# %%
# This is what df.corr() looks like
df.corr()
# Out:
#               AveragePrice  Total Volume   4046   4225   4770  Total Bags  \
# AveragePrice         1.000        -0.344 -0.342 -0.268 -0.241      -0.308
# Total Volume        -0.344         1.000  0.895  0.873  0.649       0.925
# 4046                -0.342         0.895  1.000  0.603  0.509       0.776
# 4225                -0.268         0.873  0.603  1.000  0.623       0.754
# 4770                -0.241         0.649  0.509  0.623  1.000       0.553
# Total Bags          -0.308         0.925  0.776  0.754  0.553       1.000
# Small Bags          -0.296         0.921  0.762  0.783  0.566       0.970
# Large Bags          -0.249         0.668  0.590  0.466  0.343       0.788
# XLarge Bags         -0.154         0.538  0.436  0.450  0.588       0.555
#
#               Small Bags  Large Bags  XLarge Bags
# AveragePrice      -0.296      -0.249       -0.154
# Total Volume       0.921       0.668        0.538
# 4046               0.762       0.590        0.436
# 4225               0.783       0.466        0.450
# 4770               0.566       0.343        0.588
# Total Bags         0.970       0.788        0.555
# Small Bags         1.000       0.614        0.587
# Large Bags         0.614       1.000        0.267
# XLarge Bags        0.587       0.267        1.000

# %% [markdown]
# ---
#
# # Assignment Task 💡
#
# ## Q1
#
# Create a table that shows the sum of sales of each type of avocados (4046, 4225, 4770) in each region in 2017. Perform the task by following the steps below.

# %%
# Let dfs be a new variable that filter all data from df where year is 2017 
dfs = df.loc[(df.index > '2016-12-31') & (df.index < '2018-1-1')]
print(dfs)
# Out:
#             AveragePrice  Total Volume     4046       4225    4770  \
# Date
# 2017-12-31         1.470    113514.420 2622.700 101135.530  20.250
# 2017-12-24         1.450     77039.090 2811.710  58592.230  19.060
# 2017-12-17         1.430     70677.560 2578.950  50811.520  79.180
# 2017-12-10         1.290     92325.530 3220.050  75147.560 104.360
# 2017-12-03         1.390    139970.000 3772.000 126551.000 136.000
# ...                  ...           ...      ...        ...     ...
# 2017-01-29         1.300     17839.370 1486.340   4498.480  26.120
# 2017-01-22         1.210     16430.640 1413.930   2820.530  20.250
# 2017-01-15         1.190     17014.230 1203.870   2904.220  23.070
# 2017-01-08         1.180     14375.390 1327.980   2617.200   5.750
# 2017-01-01         1.280     15307.870  867.660   3434.020  37.300
#
#             Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# Date
# 2017-12-31    9735.940    5556.980    4178.960        0.000  conventional
# 2017-12-24   15616.090    6863.180    8752.910        0.000  conventional
# 2017-12-17   17207.910    8914.130    8293.780        0.000  conventional
# 2017-12-10   13853.560    7268.210    6585.350        0.000  conventional
# 2017-12-03    9511.000    7061.000    2450.000        0.000  conventional
# ...                ...         ...         ...          ...           ...
# 2017-01-29   11828.430   11821.760       6.670        0.000       organic
# 2017-01-22   12175.930   12073.070     102.860        0.000       organic
# 2017-01-15   12883.070   12476.570     406.500        0.000       organic
# 2017-01-08   10424.460   10283.850     140.610        0.000       organic
# 2017-01-01   10968.890   10815.880     153.010        0.000       organic
#
#                       region
# Date
# 2017-12-31            Albany
# 2017-12-24            Albany
# 2017-12-17            Albany
# 2017-12-10            Albany
# 2017-12-03            Albany
# ...                      ...
# 2017-01-29  WestTexNewMexico
# 2017-01-22  WestTexNewMexico
# 2017-01-15  WestTexNewMexico
# 2017-01-08  WestTexNewMexico
# 2017-01-01  WestTexNewMexico
#
# [5616 rows x 11 columns]

# %%
# Remove all columns from dfs except 4046, 4225, 4770, region
dfs = dfs[['4046', '4225', '4770', 'region']]
print(dfs)
# Out:
#                4046       4225    4770            region
# Date
# 2017-12-31 2622.700 101135.530  20.250            Albany
# 2017-12-24 2811.710  58592.230  19.060            Albany
# 2017-12-17 2578.950  50811.520  79.180            Albany
# 2017-12-10 3220.050  75147.560 104.360            Albany
# 2017-12-03 3772.000 126551.000 136.000            Albany
# ...             ...        ...     ...               ...
# 2017-01-29 1486.340   4498.480  26.120  WestTexNewMexico
# 2017-01-22 1413.930   2820.530  20.250  WestTexNewMexico
# 2017-01-15 1203.870   2904.220  23.070  WestTexNewMexico
# 2017-01-08 1327.980   2617.200   5.750  WestTexNewMexico
# 2017-01-01  867.660   3434.020  37.300  WestTexNewMexico
#
# [5616 rows x 4 columns]

# %%
# Using groupby and sum to group dfs, by region
dfs = dfs.groupby('region')[['4046','4225','4770']].sum()
print(dfs)
# Out:
#                              4046          4225         4770
# region
# Albany                 170502.180   4209517.840    16056.160
# Atlanta              13879908.540   3244119.300    23925.970
# BaltimoreWashington   3921146.380  25079073.590   391281.830
# Boise                 2008107.730    227152.320   430802.990
# Boston                 620136.080  22758071.060   202009.420
# BuffaloRochester       278246.840   3635037.780     3043.760
# California          114949380.300 105147465.960  7710648.670
# Charlotte             2776720.300   4505816.040   411207.190
# Chicago               4830354.300  24661931.540  6297647.510
# CincinnatiDayton       414893.140   5042195.410   105565.020
# Columbus              4201965.970   1505308.820    96631.680
# DallasFtWorth        34117555.180  13084363.230   496196.670
# Denver                8405850.380  12247146.600   775668.000
# Detroit               5053983.670   3536808.860  1420518.810
# GrandRapids            111437.920   4332215.620  1533115.100
# GreatLakes           32338028.460  72485269.790 13050240.120
# HarrisburgScranton    2484266.960   6354354.440    19243.910
# HartfordSpringfield    526359.210  11100662.020    63950.900
# Houston              33380808.800  11702179.520   649310.740
# Indianapolis           677252.750   4181914.000   114067.440
# Jacksonville          4868987.260    967134.180     8283.170
# LasVegas              5690764.750   3609415.090   338114.270
# LosAngeles           62259490.450  27523901.210  4629497.160
# Louisville             166626.540   2303955.050    12817.910
# MiamiFtLauderdale    18932974.260   4411459.870    47671.090
          figsize=(48,12))

# %% [markdown]
# ## Q3 - Shall we contribute our part to save the world?
#
# Novel Coronavirus (2019-nCoV), commonly known as 武漢肺炎 in greater China, outbreaks the world. In this task you are required to present the data published from World Health Organization (WHO) to alert the community. Go to this website: https://www.who.int/emergencies/diseases/novel-coronavirus-2019/situation-reports to download at least 8 situation reports where figures of confirmed case around the world were published in PDF files. Choose one visualization method to produce one or two graph(s) that allows us to visualize **the rapid growth of the infection case** (temporal) and **the widespread of the virus** (spatial). Make sure your visualization comply with the following:
#
# * Your visualization must be done within this ipynb. You are not allowed to make graph in excel and embed here.
# * However, data entry and data preprocessing (finding min/max/count etc..) can be done via excel and save as a csv file.
# * Only data or data derived from the situation reports can be used. You are not allowed to consume external data even through these source are authentic. The reason is solely because we can have a fair set of data for everyone.
# * You can, however, use any data published in these reports. Remember, your report needs to cover both temporal and spatial data.
# * Do not restrict yourself to the types of graph that we have covered in this assignment or the lecture note.
# * Your graph should follow the design rules taught in the lecture note (P.9)
# * Only one or two graph(s) should be produced. The maximum mark for submitting only one graph and two graph(s) will be the same. If you submit more than two graphs. Whenever more than two graphs are submitted for this quesiton, only the first two graphs will be graded.
# * State clearly your target audiance (TA) if it is not general public. For example, if you want to customize your TA to be HKBU students or elderly.
#
# | Target Audiance |
# |:-:|
# | 💡General Public and garphs are interactive.|
# | And the tools is pyecharts with the newest version.|
# |To generate these graphes, pyecharts should be installed by 'pip(3) install pyecharts' or just open the render.html with generated graphes. |
#
# Marking Criteria:
# * Ability to express the severity in rapid growth and widespread of the virus.
# * Compliance of the design rules told in the lecture.
# * Appropriate graph legend/title/label
# * Ability to wisely select data to present.

# %%
# #Data Preprocessing

# import pdfplumber
# import pandas as pd

# with pdfplumber.open("20200201-sitrep-12-ncov.pdf") as pdf:
#     page = pdf.pages[2]   # 第一页的信息
#     text = page.extract_text()
#     table = page.extract_tables()
#     for t in table:
#         # 得到的table是嵌套list类型，转化成DataFrame更加方便查看和分析
#         df12 = pd.DataFrame(t[1:], columns=t[0])
# # Remove "WHO Regional Office" and clear none value rows.
# # del df12['WHO Regional Office']
# df12.dropna(axis=0, how='any', inplace=True)
# #clear blank value rows and the total row
# df12 = df12.drop(df12[df12["Province/Region/City"]==''].index).reset_index(drop=True)
# # df12 = df12.sort_values('Confirmed Cases',ascending=False)
# df12=df12.drop([34])
# df12.to_csv("20200201-sitrep-12-ncov-China.csv",index=None)

# with pdfplumber.open("20200202-sitrep-13-ncov-v3.pdf") as pdf:
#     page = pdf.pages[2]   # 第一页的信息
#     text = page.extract_text()

#     table = page.extract_tables()
#     for t in table:
#         # 得到的table是嵌套list类型，转化成DataFrame更加方便查看和分析
#         df13 = pd.DataFrame(t[1:], columns=t[0])

# # Remove "WHO Regional Office" and clear none value rows.
# # del df12['WHO Regional Office']
# df13.dropna(axis=0, how='any', inplace=True)
# #clear blank value rows and the total row
# df13 = df13.drop(df13[df13["Province/Region/City"]==''].index).reset_index(drop=True)
# df13=df13.drop([34])
# df13.to_csv("20200202-sitrep-13-ncov-China.csv",index=None)

# with pdfplumber.open("20200203-sitrep-14-ncov.pdf") as pdf:
#     page = pdf.pages[2]   # 第一页的信息
#     text = page.extract_text()

#     table = page.extract_tables()
#     for t in table:
#         # 得到的table是嵌套list类型，转化成DataFrame更加方便查看和分析
#         df14 = pd.DataFrame(t[1:], columns=t[0])

# # Remove "WHO Regional Office" and clear none value rows.
# # del df12['WHO Regional Office']
# df14.dropna(axis=0, how='any', inplace=True)
# #clear blank value rows and the total row
# df14 = df14.drop(df14[df14["Province/Region/City"]==''].index).reset_index(drop=True)
# df14 = df14.drop([34])
# df14.to_csv("20200203-sitrep-14-ncov-China.csv",index=None)

# with pdfplumber.open("20200204-sitrep-15-ncov.pdf") as pdf:
#     page = pdf.pages[1]   # 第一页的信息
#     text = page.extract_text()

#     table = page.extract_tables()
#     for t in table:
#         # 得到的table是嵌套list类型，转化成DataFrame更加方便查看和分析
#         df15 = pd.DataFrame(t[1:], columns=t[0])

# # Remove "WHO Regional Office" and clear none value rows.
# # del df12['WHO Regional Office']
# df15.dropna(axis=0, how='any', inplace=True)
# #clear blank value rows and the total row
# df15 = df15.drop(df15[df15["Province/Region/City"]==''].index).reset_index(drop=True)
# df15 = df15.drop([34])
# df15.to_csv("20200204-sitrep-15-ncov-China.csv",index=None)

# with pdfplumber.open("20200205-sitrep-16-ncov.pdf") as pdf:
#     page = pdf.pages[2]   # 第一页的信息
#     text = page.extract_text()

#     table = page.extract_tables()
#     for t in table:
#         # 得到的table是嵌套list类型，转化成DataFrame更加方便查看和分析
#         df16 = pd.DataFrame(t[1:], columns=t[0])

# # Remove "WHO Regional Office" and clear none value rows.
# # del df12['WHO Regional Office']
# df16.dropna(axis=0, how='any', inplace=True)
# #clear blank value rows and the total row
# df16 = df16.drop(df16[df16["Province/Region/City"]==''].index).reset_index(drop=True)
# df16 = df16.drop([34])
# df16.to_csv("20200205-sitrep-16-ncov-China.csv",index=None)

# with pdfplumber.open("20200206-sitrep-17-ncov.pdf") as pdf:
#     page = pdf.pages[2]   # 第一页的信息
#     text = page.extract_text()

#     table = page.extract_tables()
#     for t in table:
#         # 得到的table是嵌套list类型，转化成DataFrame更加方便查看和分析
#         df17 = pd.DataFrame(t[1:], columns=t[0])

# # Remove "WHO Regional Office" and clear none value rows.
# # del df12['WHO Regional Office']
# df17.dropna(axis=0, how='any', inplace=True)
# #clear blank value rows and the total row
# df17 = df17.drop(df17[df17["Province/Region/City"]==''].index).reset_index(drop=True)
# df17 = df17.drop([34])
# df17["Confirmed Cases"] = [''.join(x.split()) for x in df17["Confirmed Cases"].values]
# df17.to_csv("20200206-sitrep-17-ncov-China.csv",index=None)

# with pdfplumber.open("20200207-sitrep-18-ncov.pdf") as pdf:
#     page = pdf.pages[1]   # 第一页的信息
#     text = page.extract_text()

#     table = page.extract_tables()
#     for t in table:
#         # 得到的table是嵌套list类型，转化成DataFrame更加方便查看和分析
#         df18 = pd.DataFrame(t[1:], columns=t[0])

# # Remove "WHO Regional Office" and clear none value rows.
# # del df12['WHO Regional Office']
# df18.dropna(axis=0, how='any', inplace=True)
# #clear blank value rows and the total row
# df18 = df18.drop(df18[df18["Province/Region/City"]==''].index).reset_index(drop=True)
# df18 = df18.drop([34])
# df18["Confirmed Cases"] = [''.join(x.split()) for x in df18["Confirmed Cases"].values]
# df18.to_csv("20200207-sitrep-18-ncov-China.csv",index=None)

# with pdfplumber.open("20200208-sitrep-19-ncov.pdf") as pdf:
#     page = pdf.pages[2]   # 第一页的信息
#     text = page.extract_text()

#     table = page.extract_tables()
#     for t in table:
#         # 得到的table是嵌套list类型，转化成DataFrame更加方便查看和分析
#         df19 = pd.DataFrame(t[1:], columns=t[0])

# # Remove "WHO Regional Office" and clear none value rows.
# # del df12['WHO Regional Office']
# df19.dropna(axis=0, how='any', inplace=True)
# #clear blank value rows and the total row
# df19 = df19.drop(df19[df19["Province/Region/City"]==''].index).reset_index(drop=True)
# df19 = df19.drop([34])
# df19["Confirmed Cases"] = [''.join(x.split()) for x in df19["Confirmed Cases"].values]
# df19.to_csv("20200208-sitrep-19-ncov-China.csv",index=None)

# date = ["2020-02-02"]*34
# df13['Date'] = date
# df13['Date'] = pd.to_datetime(df13['Date']) # convert date column to datetime
# date = ["2020-02-01"]*34
# df12['Date'] = date
# df12['Date'] = pd.to_datetime(df12['Date']) # convert date column to datetime
# date = ["2020-02-03"]*34
# df14['Date'] = date
# df14['Date'] = pd.to_datetime(df14['Date']) # convert date column to datetime
# date = ["2020-02-04"]*34
# df15['Date'] = date
# df15['Date'] = pd.to_datetime(df15['Date']) # convert date column to datetime
# date = ["2020-02-05"]*34
# df16['Date'] = date
# df16['Date'] = pd.to_datetime(df16['Date']) # convert date column to datetime
# date = ["2020-02-06"]*34
# df17['Date'] = date
# df17['Date'] = pd.to_datetime(df17['Date']) # convert date column to datetime
# df18['Date'] = date
# df18['Date'] = pd.to_datetime(df18['Date']) # convert date column to datetime
# df19['Date'] = date
# df19['Date'] = pd.to_datetime(df19['Date']) # convert date column to datetime
# df = df12.append(df13).append(df14).append(df15).append(df16).append(df17).append(df18).append(df19)
# df.reset_index(drop=True)

# pattern1 = ["Hong Kong Sar"]
# pattern2 = ["Taipei and environs"]
# pattern3 = ["Macao Sar", "Macau SAR","Macau SAR","Macao Sar" ]


# df["Province/Region/City"] = ["Hong Kong SAR" if x in pattern1 else x for x in df["Province/Region/City"]]
# df["Province/Region/City"] = ["Taipei" if x in pattern2 else x for x in df["Province/Region/City"]]
# df["Province/Region/City"] = ["Macao SAR" if x in pattern3 else x for x in df["Province/Region/City"]]

# dfp = df.groupby('Province/Region/City')
# elem = df["Province/Region/City"].values
# elem = list(set(elem))
# import numpy as np
# output = []
# for i in elem:
#     n = dfp.get_group(str(i))
#     l = list(n["Confirmed Cases"])+[i]
#     output.append(l)
# name = ['2012/02/12','2012/02/13','2012/02/14','2012/02/15','2012/02/16','2012/02/17','2012/02/18','2012/02/19','Province']
# record = pd.DataFrame(columns=name, data = output)
# data = record.set_index(["Province"])
# data.to_csv("data.csv")

# %%
# Put your code here
import pandas as pd

from pyecharts import options as opts
from pyecharts.charts import Line, Map, Timeline, Page, Grid, Bar
from pyecharts.globals import ChartType

# def Minmax(list):
#     Max = max(list)
#     Min = min(list)
#     length = len(list)
#     dis = Max - Min
#     for i in range(length):
#         list[i] =( (list[i] - Min)/dis)*100
#     return list

def timeline_map() -> Timeline:
    tl = Timeline()
    #read the data from csv
    date = list(range(20200201,20200209))
    num = list(range(12,20))
    for (i,j) in zip(date, num):
        Provinces = pd.read_csv("{}-sitrep-{}-ncov_China_cn.csv".format(i,j), encoding = 'GB2312')
        locals()['arr'+str(j)] = Provinces.values 
        #draw the geo graph of each csv
        m = (
            Map( init_opts=opts.InitOpts( width  = "36000px",height  = "20000px",theme="LIGHT",))

            .add( "Confirmed Cases of Novel Coronavirus-infected", locals()['arr'+str(j)],)

            #disable the label
            .set_series_opts( label_opts=opts.LabelOpts( is_show = False, formatter = '{b}Confirmed Cases : ' + '{@[2]}', position = 'inside', font_style = "bold", font_size = 12,),)
            #enable the piecewise,show the each provinces' patients-growth in geo graph
            .set_global_opts( visualmap_opts = opts.VisualMapOpts( type_ = "color", 
                                                                  is_piecewise=True, 
                                                                  pieces=[ {"min": 0, "max": 99, "label": "[0,99]",},
                                                                          {"min": 100, "max": 499, "label": "[100,499]", },
                                                                          {"min": 500, "max": 999, "label": "[500,999]", },
                                                                          {"min": 1000, "max": 9999, "label": "[1000,9999]", },
                                                                          {"min": 10000,  "label": "Above 10000",},
                                                                         ],
                                                                  pos_top = "middle"),
                             #set the title
                             title_opts = opts.TitleOpts(title = "{} COVID-19 in China".format(i),pos_top = "top"),
                            legend_opts = opts.LegendOpts(is_show = False)
                            )
            
        )
        #add each graph into timeline
        tl.add(m, "Date: {}".format(i))
    
    return tl           

def line_base() -> Line:
    #read the data from csv
    data = pd.read_csv("data.csv",header =0)
    data = data.sort_values('2012/02/19', ascending=False)
    data=data[2:6]
    col = data.T
    i = 0
    line = (
        Line(init_opts=opts.InitOpts( ))
        .add_xaxis(list(data.iloc[:0,1:]))
        .set_global_opts(title_opts=opts.TitleOpts(title="The Top 5 Province of Patients Population Growth ",
                                                  subtitle="Not include outlier Hubei"),
                xaxis_opts=opts.AxisOpts(
                    axistick_opts=opts.AxisTickOpts(is_align_with_label=True),
                    is_scale=False,
                    boundary_gap=False,
                ), 
                yaxis_opts=opts.AxisOpts(
                    axistick_opts=opts.AxisTickOpts(is_align_with_label=True),
                    name="Number of patient"
                ), 
                legend_opts = opts.LegendOpts(pos_top = 30
                                             )
                        )
        .set_series_opts(xaxis_opts=opts.AxisOpts(name_rotate=60))
    
    )
    for i in col:
        locals()[str(i)] = col[i]
        name = list(locals()[str(i)])[:1]
        value = list(locals()[str(i)])[1:]
#         value = Minmax(value)
        locals()["line"+str(i)]= (
            Line()
            .add_xaxis(list(data.iloc[:0,1:]))
            .add_yaxis("{}".format(name), value)
            

        )
        line.overlap(locals()["line"+str(i)])
        
    
    return line   

def grid_base(n) -> Grid:
    c = (
        n
    )
    grid=Grid()
    grid.add(c,grid_opts=opts.GridOpts(pos_top="30%"))

    return grid

def bar_xyaxis_name() -> Bar:
    #read the data from csv
    data = pd.read_csv("data.csv",header =0)
    dataSum = data.sort_values('2012/02/19', ascending=False)
    del dataSum["Province"]
    dataSum.loc["Sum of Patients in each date"] =dataSum.apply(lambda x:x.sum()) 
    valueY = list(dataSum.loc["Sum of Patients in each date"].values)
    bar = (
        Bar()
        .add_xaxis(list(data.iloc[:0,1:]))
        .add_yaxis("Total patients number", [11821, 14411, 17238, 20471, 24363, 28060, 31211, 34598])
        .set_global_opts(
            title_opts=opts.TitleOpts(title="Patients with COVID-19 growth in China"),
            yaxis_opts=opts.AxisOpts(name="Number of patient"),
            xaxis_opts=opts.AxisOpts(name="Date"),
        )
    )
    return bar


def main(raw=0):
    page=Page()
    page.add(timeline_map())
    page.add(bar_xyaxis_name())
    line_grap = line_base()
    result = page.add(\
        grid_base(line_grap)
    )
    
    return result
if __name__ == '__main__':
    
    t = main()
#save in local html
Page.render(t)
    
#display the graph in notebok
Page.render_notebook(t)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="dacb857e7b0b40c8b77583b10409dc92" style="width:900px; height:500px;"></div>
#         <div id="de219758dab741988efecf44bd0ac0d2" style="width:900px; height:500px;"></div>
#         <div id="da4796b2532544cd90cf6ccec14fb7bd" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_dacb857e7b0b40c8b77583b10409dc92 = echarts.init(
#                     document.getElementById('dacb857e7b0b40c8b77583b10409dc92'), 'white', {renderer: 'canvas'});
#                 var option_dacb857e7b0b40c8b77583b10409dc92 = {
#     "baseOption": {
#         "series": [
#             {
#                 "type": "map",
#                 "name": "Confirmed Cases of Novel Coronavirus-infected",
#                 "label": {
#                     "show": false,
#                     "position": "inside",
#                     "margin": 8,
#                     "fontSize": 12,
#                     "fontStyle": "bold",
#                     "formatter": "{b}Confirmed Cases : {@[2]}"
#                 },
#                 "mapType": "china",
#                 "data": [
#                     {
#                         "name": "\u6e56\u5317",
#                         "value": 24953
#                     },
#                     {
#                         "name": "\u5e7f\u4e1c",
#                         "value": 1075
#                     },
#                     {
#                         "name": "\u6d59\u6c5f",
#                         "value": 1048
#                     },
#                     {
#                         "name": "\u6cb3\u5357",
#                         "value": 981
#                     },
#                     {
#                         "name": "\u6e56\u5357",
#                         "value": 803
#                     },
#                     {
#                         "name": "\u5b89\u5fbd",
#                         "value": 733
#                     },
#                     {
#                         "name": "\u6c5f\u897f",
#                         "value": 698
#                     },
#                     {
#                         "name": "\u6c5f\u82cf",
#                         "value": 439
#                     },
#                     {
#                         "name": "\u91cd\u5e86",
#                         "value": 426
#                     },
#                     {
#                         "name": "\u5c71\u4e1c",
#                         "value": 407
#                     },
#                     {
#                         "name": "\u56db\u5ddd",
#                         "value": 363
#                     },
#                     {
#                         "name": "\u5317\u4eac",
#                         "value": 315
#                     },
#                     {
#                         "name": "\u9ed1\u9f99\u6c5f",
#                         "value": 282
#                     },
#                     {
#                         "name": "\u4e0a\u6d77",
#                         "value": 281
#                     },
#                     {
#                         "name": "\u798f\u5efa",
#                         "value": 239
#                     },
#                     {
#                         "name": "\u9655\u897f",
#                         "value": 195
#                     },
#                     {
#                         "name": "\u6cb3\u5317",
#                         "value": 195
#                     },
#                     {
#                         "name": "\u5e7f\u897f",
#                         "value": 183
#                     },
#                     {
#                         "name": "\u4e91\u5357",
#                         "value": 138
#                     },
#                     {
#                         "name": "\u6d77\u5357",
#                         "value": 123
#                     },
#                     {
#                         "name": "\u5c71\u897f",
#                         "value": 104
#                     },
#                     {
#                         "name": "\u8fbd\u5b81",
#                         "value": 99
#                     },
#                     {
#                         "name": "\u8d35\u5dde",
#                         "value": 89
#                     },
#                     {
#                         "name": "\u5929\u6d25",
#                         "value": 81
#                     },
#                     {
#                         "name": "\u7518\u8083",
#                         "value": 71
#                     },
#                     {
#                         "name": "\u5409\u6797",
#                         "value": 69
#                     },
#                     {
#                         "name": "\u5185\u8499\u53e4",
#                         "value": 50
#                     },
#                     {
#                         "name": "\u5b81\u590f",
#                         "value": 45
#                     },
#                     {
#                         "name": "\u65b0\u7586",
#                         "value": 42
#                     },
#                     {
#                         "name": "\u9999\u6e2f",
#                         "value": 26
#                     },
#                     {
#                         "name": "\u9752\u6d77",
#                         "value": 18
#                     },
#                     {
#                         "name": "\u53f0\u6e7e",
#                         "value": 16
#                     },
#                     {
#                         "name": "\u6fb3\u95e8",
#                         "value": 10
#                     },
#                     {
#                         "name": "\u897f\u85cf",
#                         "value": 1
#                     }
#                 ],
#                 "roam": true,
#                 "zoom": 1,
#                 "showLegendSymbol": true,
#                 "emphasis": {},
#                 "rippleEffect": {
#                     "show": true,
#                     "brushType": "stroke",
#                     "scale": 2.5,
#                     "period": 4
#                 }
#             }
#         ],
#         "timeline": {
#             "axisType": "category",
#             "orient": "horizontal",
#             "autoPlay": false,
#             "controlPosition": "left",
#             "loop": true,
#             "rewind": false,
#             "show": true,
#             "inverse": false,
#             "bottom": "-5px",
#             "data": [
#                 "Date: 20200201",
#                 "Date: 20200202",
#                 "Date: 20200203",
#                 "Date: 20200204",
#                 "Date: 20200205",
#                 "Date: 20200206",
#                 "Date: 20200207",
#                 "Date: 20200208"
#             ]
#         },
#         "visualMap": {
#             "show": true,
#             "type": "piecewise",
#             "min": 0,
#             "max": 100,
#             "inRange": {
#                 "color": [
#                     "#50a3ba",
#                     "#eac763",
#                     "#d94e5d"
#                 ]
#             },
#             "calculable": true,
#             "inverse": false,
#             "splitNumber": 5,
#             "orient": "vertical",
#             "top": "middle",
#             "showLabel": true,
#             "itemWidth": 20,
#             "itemHeight": 14,
#             "borderWidth": 0,
#             "pieces": [
#                 {
#                     "min": 0,
#                     "max": 99,
#                     "label": "[0,99]"
#                 },
#                 {
#                     "min": 100,
#                     "max": 499,
#                     "label": "[100,499]"
#                 },
#                 {
#                     "min": 500,
#                     "max": 999,
#                     "label": "[500,999]"
#                 },
#                 {
#                     "min": 1000,
#                     "max": 9999,
#                     "label": "[1000,9999]"
#                 },
#                 {
#                     "min": 10000,
#                     "label": "Above 10000"
